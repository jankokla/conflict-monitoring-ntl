# %% [markdown]
# # Study Areas
#
# Our analysis is constrained by the limited availability of SDGSAT-1 satellite imagery across the Global South, with data currently covering only ten regions. Consequently, the study areas are restricted to these countries and their corresponding regions where valid imagery exists. The research focuses on administrative level 2 units, as defined by the **Global Administrative Areas (GADM)** dataset, as well as smaller settlements—such as towns and villages—identified through **OpenStreetMap (OSM)**.
#
# NB! Currently, a good methodology for finding towns / villages from OSM has not been found.
#
# The subsequent analysis presents the specific countries and administrative units that can be included based on the spatial coverage of SDGSAT-1 tiles and illustrates the distribution of smaller populated areas within these boundaries.

# %%
import folium
import pygadm
import pandas as pd
from shapely import unary_union
from conflict_monitoring_ntl.case_studies import get_tiles_paths
from conflict_monitoring_ntl.viz import plot_admin_map_with_tiles
from conflict_monitoring_ntl.utils import (
    get_raster_polygon, 
    reproject_gdf, 
    get_raster_gdf,
)

# %%
tiles_paths = get_tiles_paths()

gdfs = []

for tiles_tuple in tiles_paths:
    gdfs.append(get_raster_gdf(*tiles_tuple, crs="EPSG:4326"))

gdf = pd.concat(gdfs)
global_centroid = unary_union(gdf.geometry).centroid
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# General overview of the coverage:

# %%
m = folium.Map(
    location=[global_centroid.y, global_centroid.x], 
    zoom_start=3, 
    tiles="CartoDB positron"
)

for _, row in gdf.iterrows():
    folium.GeoJson(
        data=row.geometry,
        name="Tiles",
        style_function=lambda _: {
            "fillColor": "blue",
            "color": "blue",
            "weight": 1
        }
    ).add_to(m)

m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_300b7355a43d28796c777be13ae1a5b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_300b7355a43d28796c777be13ae1a5b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_300b7355a43d28796c777be13ae1a5b9 = L.map(
#                 &quot;map_300b7355a43d28796c777be13ae1a5b9&quot;,
#                 {
#                     center: [14.406699524836824, 33.95500515364154],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_df1d9577b31a092ad946f4948de48a93 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_df1d9577b31a092ad946f4948de48a93.addTo(map_300b7355a43d28796c777be13ae1a5b9);
#
#
#         function geo_json_6e291a5c154b5ec51d535c29b74c6ff0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_6e291a5c154b5ec51d535c29b74c6ff0_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_6e291a5c154b5ec51d535c29b74c6ff0 = L.geoJson(null, {
#                 onEachFeature: geo_json_6e291a5c154b5ec51d535c29b74c6ff0_onEachFeature,
#
#                 style: geo_json_6e291a5c154b5ec51d535c29b74c6ff0_styler,
#             ...{
# }
#         });
#
#         function geo_json_6e291a5c154b5ec51d535c29b74c6ff0_add (data) {
#             geo_json_6e291a5c154b5ec51d535c29b74c6ff0
#                 .addData(data);
#         }
#             geo_json_6e291a5c154b5ec51d535c29b74c6ff0_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[26.2520041556793, 9.713257854156916], [24.231854821020526, 9.702882989451894], [24.200008980604437, 12.98702554245444], [25.62810715423525, 12.998494210349996], [25.626439939558058, 13.298233295151025], [27.66093105266959, 13.301084222428555], [27.65311207277248, 9.96937276478266], [26.251428107266456, 9.969172359138351], [26.2520041556793, 9.713257854156916]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_6e291a5c154b5ec51d535c29b74c6ff0.addTo(map_300b7355a43d28796c777be13ae1a5b9);
#
#
#         function geo_json_82b33994ce4aedf2f98b06031ccf528d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_82b33994ce4aedf2f98b06031ccf528d_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_82b33994ce4aedf2f98b06031ccf528d = L.geoJson(null, {
#                 onEachFeature: geo_json_82b33994ce4aedf2f98b06031ccf528d_onEachFeature,
#
#                 style: geo_json_82b33994ce4aedf2f98b06031ccf528d_styler,
#             ...{
# }
#         });
#
#         function geo_json_82b33994ce4aedf2f98b06031ccf528d_add (data) {
#             geo_json_82b33994ce4aedf2f98b06031ccf528d
#                 .addData(data);
#         }
#             geo_json_82b33994ce4aedf2f98b06031ccf528d_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-2.8350750738335946, 13.039856711453965], [-4.886750607054003, 13.033037440965499], [-4.915075403083131, 16.312098385685378], [-3.4662147359261994, 16.320268317958764], [-3.466929195574861, 16.618873354534237], [-1.3950759885624662, 16.6131996833501], [-1.4196127492072026, 13.288578755788922], [-2.8349053177403936, 13.293433553046253], [-2.8350750738335946, 13.039856711453965]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_82b33994ce4aedf2f98b06031ccf528d.addTo(map_300b7355a43d28796c777be13ae1a5b9);
#
#
#         function geo_json_903350624082cfd2ecf1f2d31daa53a0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_903350624082cfd2ecf1f2d31daa53a0_onEachFeature(feature, layer) {

# %% [markdown]
# ## Sudan

# %%
country = "Sudan"

tiles_paths = get_tiles_paths(country)
polygon, crs = get_raster_polygon(*tiles_paths)

raster_gdf = get_raster_gdf(*tiles_paths, crs="EPSG:4326")
admin_gdf = pygadm.Items(name=country, content_level=2)
country_gdf = pygadm.Items(name=country, content_level=0)

admin_gdf = reproject_gdf(admin_gdf, crs)
admin_gdf["is_within_raster"] = admin_gdf["geometry_proj"].apply(
    lambda geom: geom.within(polygon)
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Following regions are available:

# %%
regions_within = admin_gdf[admin_gdf.is_within_raster].NAME_2.tolist()
print(", ".join(regions_within))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Nyala, Tulus

# %%
plot_admin_map_with_tiles(country_gdf, raster_gdf, admin_gdf, zoom_start=5)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f11987da9eb00597430ac3deba09bc79 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f11987da9eb00597430ac3deba09bc79&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f11987da9eb00597430ac3deba09bc79 = L.map(
#                 &quot;map_f11987da9eb00597430ac3deba09bc79&quot;,
#                 {
#                     center: [16.049371654119376, 30.005645900465886],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f5454aa6b7cdf2b7999b09649d8e98bc = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f5454aa6b7cdf2b7999b09649d8e98bc.addTo(map_f11987da9eb00597430ac3deba09bc79);
#
#
#         function geo_json_7a958db12bcc4a73d6d4009b4ade5c0d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_7a958db12bcc4a73d6d4009b4ade5c0d_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_7a958db12bcc4a73d6d4009b4ade5c0d = L.geoJson(null, {
#                 onEachFeature: geo_json_7a958db12bcc4a73d6d4009b4ade5c0d_onEachFeature,
#
#                 style: geo_json_7a958db12bcc4a73d6d4009b4ade5c0d_styler,
#             ...{
# }
#         });
#
#         function geo_json_7a958db12bcc4a73d6d4009b4ade5c0d_add (data) {
#             geo_json_7a958db12bcc4a73d6d4009b4ade5c0d
#                 .addData(data);
#         }
#             geo_json_7a958db12bcc4a73d6d4009b4ade5c0d_add({&quot;bbox&quot;: [24.200008980604437, 9.702882989451894, 27.66093105266959, 13.301084222428555], &quot;features&quot;: [{&quot;bbox&quot;: [24.200008980604437, 9.702882989451894, 27.66093105266959, 13.301084222428555], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[26.2520041556793, 9.713257854156916], [24.231854821020526, 9.702882989451894], [24.200008980604437, 12.98702554245444], [25.62810715423525, 12.998494210349996], [25.626439939558058, 13.298233295151025], [27.66093105266959, 13.301084222428555], [27.65311207277248, 9.96937276478266], [26.251428107266456, 9.969172359138351], [26.2520041556793, 9.713257854156916]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_7a958db12bcc4a73d6d4009b4ade5c0d.addTo(map_f11987da9eb00597430ac3deba09bc79);
#
#
#         function geo_json_4315369b4ac8792d30d8b7282a37283e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#F7931F&quot;, &quot;fillColor&quot;: &quot;#F7931F&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_4315369b4ac8792d30d8b7282a37283e_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_4315369b4ac8792d30d8b7282a37283e = L.geoJson(null, {
#                 onEachFeature: geo_json_4315369b4ac8792d30d8b7282a37283e_onEachFeature,
#
#                 style: geo_json_4315369b4ac8792d30d8b7282a37283e_styler,
#             ...{
# }
#         });
#
#         function geo_json_4315369b4ac8792d30d8b7282a37283e_add (data) {
#             geo_json_4315369b4ac8792d30d8b7282a37283e
#                 .addData(data);
#         }
#             geo_json_4315369b4ac8792d30d8b7282a37283e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[33.1141, 14.8749], [32.9916, 14.9108], [32.9184, 15.1209], [32.7785, 15.0545], [32.7527, 15.0852], [32.7441, 15.1256], [32.6937, 15.1501], [32.6806, 15.1662], [32.6433, 15.1669], [32.6391, 15.1788], [32.5976, 15.1887], [32.5891, 15.1965], [32.5628, 15.1867], [32.481, 15.231], [32.5553, 15.2237], [33.026, 15.265], [33.028, 15.254], [33.036, 15.248], [33.046, 15.243], [33.071, 15.239], [33.079, 15.234], [33.086, 15.213], [33.091, 15.204], [33.127, 15.157], [33.142, 15.144], [33.162, 15.136], [33.173, 15.126], [33.179, 15.118], [33.182, 15.108], [33.184, 15.068], [33.186, 15.058], [33.192, 15.05], [33.216, 15.031], [33.221, 15.023], [33.2228, 15.0123], [33.222, 14.998], [33.213, 14.979], [33.211, 14.967], [33.211, 14.955], [33.213, 14.947], [33.218, 14.938], [33.219, 14.927], [33.216, 14.916], [33.216, 14.903], [33.2187, 14

# %%
# aoi_str = get_area_of_interest(country)
# aoi = ox.geocoder.geocode_to_gdf(aoi_str)
# aoi.explore()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# *For a cleaner view of the remaining locations, code input has been concealed.*

# %% [markdown]
# ## Mali

# %%
country = "Mali"

tiles_paths = get_tiles_paths(country)
polygon, crs = get_raster_polygon(*tiles_paths)

raster_gdf = get_raster_gdf(*tiles_paths, crs="EPSG:4326")
admin_gdf = pygadm.Items(name=country, content_level=2)
country_gdf = pygadm.Items(name=country, content_level=0)

admin_gdf = reproject_gdf(admin_gdf, crs)
admin_gdf["is_within_raster"] = admin_gdf["geometry_proj"].apply(
    lambda geom: geom.within(polygon)
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Following regions are available:

# %%
regions_within = admin_gdf[admin_gdf.is_within_raster].NAME_2.tolist()
print(", ".join(regions_within))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Bandiagara, Bankass, Koro, Mopti

# %%
plot_admin_map_with_tiles(country_gdf, raster_gdf, admin_gdf, zoom_start=5)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_da6af8af20bd1148a44af0e875e8d82b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_da6af8af20bd1148a44af0e875e8d82b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_da6af8af20bd1148a44af0e875e8d82b = L.map(
#                 &quot;map_da6af8af20bd1148a44af0e875e8d82b&quot;,
#                 {
#                     center: [17.356246609827334, -3.5221601868498698],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5980db6f454116c8112f3c61994ade6f = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5980db6f454116c8112f3c61994ade6f.addTo(map_da6af8af20bd1148a44af0e875e8d82b);
#
#
#         function geo_json_478f9d01408c0a59e842e802236cd081_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_478f9d01408c0a59e842e802236cd081_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_478f9d01408c0a59e842e802236cd081 = L.geoJson(null, {
#                 onEachFeature: geo_json_478f9d01408c0a59e842e802236cd081_onEachFeature,
#
#                 style: geo_json_478f9d01408c0a59e842e802236cd081_styler,
#             ...{
# }
#         });
#
#         function geo_json_478f9d01408c0a59e842e802236cd081_add (data) {
#             geo_json_478f9d01408c0a59e842e802236cd081
#                 .addData(data);
#         }
#             geo_json_478f9d01408c0a59e842e802236cd081_add({&quot;bbox&quot;: [-4.915075403083131, 13.033037440965499, -1.3950759885624662, 16.618873354534237], &quot;features&quot;: [{&quot;bbox&quot;: [-4.915075403083131, 13.033037440965499, -1.3950759885624662, 16.618873354534237], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-2.8350750738335946, 13.039856711453965], [-4.886750607054003, 13.033037440965499], [-4.915075403083131, 16.312098385685378], [-3.4662147359261994, 16.320268317958764], [-3.466929195574861, 16.618873354534237], [-1.3950759885624662, 16.6131996833501], [-1.4196127492072026, 13.288578755788922], [-2.8349053177403936, 13.293433553046253], [-2.8350750738335946, 13.039856711453965]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_478f9d01408c0a59e842e802236cd081.addTo(map_da6af8af20bd1148a44af0e875e8d82b);
#
#
#         function geo_json_2b5beed23fa61390a446a7d61708d02f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#F7931F&quot;, &quot;fillColor&quot;: &quot;#F7931F&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_2b5beed23fa61390a446a7d61708d02f_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_2b5beed23fa61390a446a7d61708d02f = L.geoJson(null, {
#                 onEachFeature: geo_json_2b5beed23fa61390a446a7d61708d02f_onEachFeature,
#
#                 style: geo_json_2b5beed23fa61390a446a7d61708d02f_styler,
#             ...{
# }
#         });
#
#         function geo_json_2b5beed23fa61390a446a7d61708d02f_add (data) {
#             geo_json_2b5beed23fa61390a446a7d61708d02f
#                 .addData(data);
#         }
#             geo_json_2b5beed23fa61390a446a7d61708d02f_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-8.0089, 12.5758], [-8.0176, 12.578], [-8.0217, 12.5822], [-8.027, 12.5845], [-8.0349, 12.594], [-8.0376, 12.5953], [-8.0402, 12.5946], [-8.0462, 12.5803], [-8.0421, 12.5671], [-8.0542, 12.5658], [-8.0677, 12.5608], [-8.0718, 12.5669], [-8.0735, 12.579], [-8.0552, 12.6578], [-8.0481, 12.6793], [-8.0459, 12.679], [-8.0412, 12.671], [-8.0399, 12.6655], [-8.0356, 12.6604], [-8.0286, 12.6608], [-8.0237, 12.6584], [-8.0182, 12.6635], [-8.0167, 12.6676], [-8.017, 12.6716], [-8.0202, 12.6736], [-8.0201, 12.677], [-8.0082, 12.6805], [-7.9851, 12.6801], [-7.9466, 12.7119], [-7.9384, 12.691], [-7.9388, 12.6887], [-7.9328, 12.6823], [-7.9172, 12.6806], [-7.9143, 12.6627], [-7.9132, 12.6636], [-7.9121, 12.6617], [-7.9081, 12.6604], [-7.907, 12.6105], [-7.9273, 12.5874], [-7.9174, 12.5209], [-7.9307, 12.5092]

# %% [markdown]
# ## Syria

# %%
country = "Syria"

tiles_paths = get_tiles_paths(country)
polygon, crs = get_raster_polygon(*tiles_paths)

raster_gdf = get_raster_gdf(*tiles_paths, crs="EPSG:4326")
admin_gdf = pygadm.Items(name=country, content_level=2)
country_gdf = pygadm.Items(name=country, content_level=0)

admin_gdf = reproject_gdf(admin_gdf, crs)
admin_gdf["is_within_raster"] = admin_gdf["geometry_proj"].apply(
    lambda geom: geom.within(polygon)
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Following regions are available:

# %%
regions_within = admin_gdf[admin_gdf.is_within_raster].NAME_2.tolist()
print(", ".join(regions_within))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Al-Hasakah, Al-Malikiyah, Al Qamishli, Ra's al-'Ayn, Ar-Raqqah, Tal Abyad

# %%
plot_admin_map_with_tiles(country_gdf, raster_gdf, admin_gdf, zoom_start=6)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83c00e3c03b63f4818c5f933ef90e076 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83c00e3c03b63f4818c5f933ef90e076&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83c00e3c03b63f4818c5f933ef90e076 = L.map(
#                 &quot;map_83c00e3c03b63f4818c5f933ef90e076&quot;,
#                 {
#                     center: [35.02453561009521, 38.526767433862325],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_76c995b745e379df918d789a6f60ab62 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_76c995b745e379df918d789a6f60ab62.addTo(map_83c00e3c03b63f4818c5f933ef90e076);
#
#
#         function geo_json_91d715ccc23047c0d5df473a4691e485_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_91d715ccc23047c0d5df473a4691e485_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_91d715ccc23047c0d5df473a4691e485 = L.geoJson(null, {
#                 onEachFeature: geo_json_91d715ccc23047c0d5df473a4691e485_onEachFeature,
#
#                 style: geo_json_91d715ccc23047c0d5df473a4691e485_styler,
#             ...{
# }
#         });
#
#         function geo_json_91d715ccc23047c0d5df473a4691e485_add (data) {
#             geo_json_91d715ccc23047c0d5df473a4691e485
#                 .addData(data);
#         }
#             geo_json_91d715ccc23047c0d5df473a4691e485_add({&quot;bbox&quot;: [38.194335960129024, 34.782975349313105, 42.632843891198206, 38.471415740713866], &quot;features&quot;: [{&quot;bbox&quot;: [38.194335960129024, 34.782975349313105, 42.632843891198206, 38.471415740713866], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[40.792457303366476, 34.782975349313105], [38.22797981437521, 34.79372666240341], [38.194335960129024, 38.114900042816146], [39.96722087219662, 38.11368105610425], [39.97198134749294, 38.471415740713866], [42.632843891198206, 38.41909299595536], [42.47752447377968, 35.056298928349165], [40.799213757040945, 35.092837214495866], [40.792457303366476, 34.782975349313105]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_91d715ccc23047c0d5df473a4691e485.addTo(map_83c00e3c03b63f4818c5f933ef90e076);
#
#
#         function geo_json_ce1de6ef980ffb7caef062d05f928c06_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#07407B&quot;, &quot;fillColor&quot;: &quot;#07407B&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_ce1de6ef980ffb7caef062d05f928c06_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_ce1de6ef980ffb7caef062d05f928c06 = L.geoJson(null, {
#                 onEachFeature: geo_json_ce1de6ef980ffb7caef062d05f928c06_onEachFeature,
#
#                 style: geo_json_ce1de6ef980ffb7caef062d05f928c06_styler,
#             ...{
# }
#         });
#
#         function geo_json_ce1de6ef980ffb7caef062d05f928c06_add (data) {
#             geo_json_ce1de6ef980ffb7caef062d05f928c06
#                 .addData(data);
#         }
#             geo_json_ce1de6ef980ffb7caef062d05f928c06_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[41.2897, 36.2492], [41.2669, 36.092], [41.258, 36.0546], [41.3811, 35.8353], [41.3943, 35.6303], [41.3214, 35.5363], [41.237, 35.5436], [41.1832, 35.5421], [41.1488, 35.5302], [41.1249, 35.5197], [41.0815, 35.5287], [41.0247, 35.5331], [40.9604, 35.5526], [40.9245, 35.566], [40.8991, 35.5735], [40.8348, 35.572], [40.7585, 35.578], [40.7376, 35.596], [40.6867, 35.6348], [40.6389, 35.6752], [40.5297, 35.7605], [40.4998, 35.7814], [40.4654, 35.7993], [40.4175, 35.8382], [40.3727, 35.8711], [40.3173, 35.9055], [40.1992, 35.9997], [40.1962, 36.0147], [40.1752, 36.0282], [40.09, 36.0999], [40.0152, 36.1598], [39.9405, 36.2166], [39.9165, 36.251], [39.9016, 36.2854], [39.9054, 36.3298], [39.9124, 36.3284], [39.931, 36.33], [39.9435, 36.3362], [39.9574, 36.3471], [39.9636, 36.3595], [39.9652, 36.3735], [39.9714, 36.384

# %% [markdown]
# ## Central African Republic

# %%
country = "Central African Republic"

tiles_paths = get_tiles_paths(country)
polygon, crs = get_raster_polygon(*tiles_paths)

raster_gdf = get_raster_gdf(*tiles_paths, crs="EPSG:4326")
admin_gdf = pygadm.Items(name=country, content_level=2)
country_gdf = pygadm.Items(name=country, content_level=0)

admin_gdf = reproject_gdf(admin_gdf, crs)
admin_gdf["is_within_raster"] = admin_gdf["geometry_proj"].apply(
    lambda geom: geom.within(polygon)
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Following regions are available:

# %%
regions_within = admin_gdf[admin_gdf.is_within_raster].NAME_2.tolist()
print(", ".join(regions_within))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Dékoa, Kaga-Bandoro, Mbrès, Bouca, Kabo

# %%
plot_admin_map_with_tiles(country_gdf, raster_gdf, admin_gdf, zoom_start=6)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86c915354b4fc23148b7720693d4e3e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86c915354b4fc23148b7720693d4e3e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86c915354b4fc23148b7720693d4e3e1 = L.map(
#                 &quot;map_86c915354b4fc23148b7720693d4e3e1&quot;,
#                 {
#                     center: [6.574479441838344, 20.48552599219851],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2bec016001bccf0734436089e2ca45c0 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2bec016001bccf0734436089e2ca45c0.addTo(map_86c915354b4fc23148b7720693d4e3e1);
#
#
#         function geo_json_62c1ad23dd7a5521bf662f2eea74ac32_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_62c1ad23dd7a5521bf662f2eea74ac32_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_62c1ad23dd7a5521bf662f2eea74ac32 = L.geoJson(null, {
#                 onEachFeature: geo_json_62c1ad23dd7a5521bf662f2eea74ac32_onEachFeature,
#
#                 style: geo_json_62c1ad23dd7a5521bf662f2eea74ac32_styler,
#             ...{
# }
#         });
#
#         function geo_json_62c1ad23dd7a5521bf662f2eea74ac32_add (data) {
#             geo_json_62c1ad23dd7a5521bf662f2eea74ac32
#                 .addData(data);
#         }
#             geo_json_62c1ad23dd7a5521bf662f2eea74ac32_add({&quot;bbox&quot;: [17.438295979987824, 5.4722066854407565, 20.799416914386804, 9.004058512613776], &quot;features&quot;: [{&quot;bbox&quot;: [17.438295979987824, 5.4722066854407565, 20.799416914386804, 9.004058512613776], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[19.432194441077545, 5.480602197349985], [17.4630652784174, 5.4722066854407565], [17.438295979987824, 8.704031321418908], [18.828209211265204, 8.71451817362709], [18.826546216009675, 8.997700452454811], [20.797936905858027, 9.004058512613776], [20.799416914386804, 5.724344200501662], [19.431549978165698, 5.72223459192251], [19.432194441077545, 5.480602197349985]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_62c1ad23dd7a5521bf662f2eea74ac32.addTo(map_86c915354b4fc23148b7720693d4e3e1);
#
#
#         function geo_json_f342dceab89b9ee46abdcfcefab20249_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#F7931F&quot;, &quot;fillColor&quot;: &quot;#F7931F&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_f342dceab89b9ee46abdcfcefab20249_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_f342dceab89b9ee46abdcfcefab20249 = L.geoJson(null, {
#                 onEachFeature: geo_json_f342dceab89b9ee46abdcfcefab20249_onEachFeature,
#
#                 style: geo_json_f342dceab89b9ee46abdcfcefab20249_styler,
#             ...{
# }
#         });
#
#         function geo_json_f342dceab89b9ee46abdcfcefab20249_add (data) {
#             geo_json_f342dceab89b9ee46abdcfcefab20249
#                 .addData(data);
#         }
#             geo_json_f342dceab89b9ee46abdcfcefab20249_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[20.9214, 7.3244], [20.9105, 7.2964], [20.9, 7.2858], [20.8889, 7.2839], [20.8856, 7.28], [20.8842, 7.2744], [20.8775, 7.2675], [20.8633, 7.2614], [20.8419, 7.2561], [20.8253, 7.2447], [20.8106, 7.2386], [20.8039, 7.2311], [20.7958, 7.2256], [20.7836, 7.225], [20.7725, 7.2283], [20.7597, 7.2367], [20.7367, 7.2408], [20.7231, 7.2486], [20.7161, 7.2492], [20.7064, 7.2456], [20.6933, 7.2458], [20.683, 7.2422], [20.6764, 7.235], [20.6697, 7.2208], [20.6678, 7.2156], [20.6669, 7.1964], [20.6592, 7.1833], [20.6569, 7.1647], [20.645, 7.1489], [20.6439, 7.1358], [20.6383, 7.1272], [20.6347, 7.1239], [20.6203, 7.1181], [20.6022, 7.0942], [20.5872, 7.0822], [20.5817, 7.0811], [20.5631, 7.065], [20.5458, 7.0625], [20.5358, 7.0669], [20.5236, 7.0689], [20.5128, 7.0661], [20.5086, 7.0636], [20.5025, 7.0558], [20.4981, 7.0461], [20.4

# %% [markdown]
# ## Democratic Republic of the Congo

# %%
country = "Democratic Republic of the Congo"

tiles_paths = get_tiles_paths(country)
polygon, crs = get_raster_polygon(*tiles_paths)

raster_gdf = get_raster_gdf(*tiles_paths, crs="EPSG:4326")
admin_gdf = pygadm.Items(name=country, content_level=2)
country_gdf = pygadm.Items(name=country, content_level=0)

admin_gdf = reproject_gdf(admin_gdf, crs)
admin_gdf["is_within_raster"] = admin_gdf["geometry_proj"].apply(
    lambda geom: geom.within(polygon)
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Following regions are available:

# %%
regions_within = admin_gdf[admin_gdf.is_within_raster].NAME_2.tolist()
print(", ".join(regions_within))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Goma, Masisi, Nyiragongo, Rutshuru, Rutshuru (ville), Bukavu, Idjwi, Kabare, Kalehe, Kamituga, Uvira (ville), Walungu

# %%
plot_admin_map_with_tiles(country_gdf, raster_gdf, admin_gdf, zoom_start=5)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2114f11690a05f2e85c7922231ba034b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2114f11690a05f2e85c7922231ba034b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2114f11690a05f2e85c7922231ba034b = L.map(
#                 &quot;map_2114f11690a05f2e85c7922231ba034b&quot;,
#                 {
#                     center: [-2.8812407758958813, 23.66023419164146],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a9a4c388196d821759ffc4d9868f4da = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9a9a4c388196d821759ffc4d9868f4da.addTo(map_2114f11690a05f2e85c7922231ba034b);
#
#
#         function geo_json_ca271e6143a4b6bd8ab57249e039ba33_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_ca271e6143a4b6bd8ab57249e039ba33_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_ca271e6143a4b6bd8ab57249e039ba33 = L.geoJson(null, {
#                 onEachFeature: geo_json_ca271e6143a4b6bd8ab57249e039ba33_onEachFeature,
#
#                 style: geo_json_ca271e6143a4b6bd8ab57249e039ba33_styler,
#             ...{
# }
#         });
#
#         function geo_json_ca271e6143a4b6bd8ab57249e039ba33_add (data) {
#             geo_json_ca271e6143a4b6bd8ab57249e039ba33
#                 .addData(data);
#         }
#             geo_json_ca271e6143a4b6bd8ab57249e039ba33_add({&quot;bbox&quot;: [27.488951178291625, -3.5366466674887787, 30.799744571150402, -0.25658337645056783], &quot;features&quot;: [{&quot;bbox&quot;: [27.488951178291625, -3.5366466674887787, 30.799744571150402, -0.25658337645056783], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[29.423055278375937, -3.5336010598755263], [27.48985716654265, -3.5366466674887787], [27.488951178291625, -0.5292034990518883], [28.874861229625967, -0.5289376941083156], [28.874800586622754, -0.25701200188838075], [30.79346043391781, -0.25658337645056783], [30.799744571150402, -3.31419468038806], [29.422514163251275, -3.318547157866609], [29.423055278375937, -3.5336010598755263]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_ca271e6143a4b6bd8ab57249e039ba33.addTo(map_2114f11690a05f2e85c7922231ba034b);
#
#
#         function geo_json_ccdcc9473a72f635ec636e4758fba02c_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#F7931F&quot;, &quot;fillColor&quot;: &quot;#F7931F&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_ccdcc9473a72f635ec636e4758fba02c_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_ccdcc9473a72f635ec636e4758fba02c = L.geoJson(null, {
#                 onEachFeature: geo_json_ccdcc9473a72f635ec636e4758fba02c_onEachFeature,
#
#                 style: geo_json_ccdcc9473a72f635ec636e4758fba02c_styler,
#             ...{
# }
#         });
#
#         function geo_json_ccdcc9473a72f635ec636e4758fba02c_add (data) {
#             geo_json_ccdcc9473a72f635ec636e4758fba02c
#                 .addData(data);
#         }
#             geo_json_ccdcc9473a72f635ec636e4758fba02c_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[23.5726, 2.3962], [23.5669, 2.4162], [23.5473, 2.4357], [23.5429, 2.4456], [23.5364, 2.4513], [23.5204, 2.4556], [23.4917, 2.4745], [23.4876, 2.4758], [23.4579, 2.4985], [23.4519, 2.5111], [23.4327, 2.5117], [23.4273, 2.5029], [23.4245, 2.51], [23.4132, 2.5265], [23.4088, 2.5302], [23.4001, 2.5336], [23.3911, 2.5295], [23.3829, 2.5438], [23.3771, 2.5431], [23.3739, 2.5451], [23.3633, 2.5628], [23.3594, 2.5651], [23.356, 2.5632], [23.3499, 2.551], [23.3479, 2.5289], [23.3386, 2.5175], [23.3384, 2.5134], [23.3442, 2.5008], [23.3427, 2.4927], [23.3381, 2.4879], [23.3345, 2.4874], [23.326, 2.4873], [23.3189, 2.4926], [23.3159, 2.4919], [23.3148, 2.49], [23.3167, 2.4822], [23.3142, 2.4762], [23.317, 2.4659], [23.3145, 2.4564], [23.3084, 2.4511], [23.2938, 2.4503], [23.2903, 2.4517], [23.282, 2.46

# %% [markdown]
# ## Yemen

# %%
country = "Yemen"

tiles_paths = get_tiles_paths(country)
polygon, crs = get_raster_polygon(*tiles_paths)

raster_gdf = get_raster_gdf(*tiles_paths, crs="EPSG:4326")
admin_gdf = pygadm.Items(name=country, content_level=2)
country_gdf = pygadm.Items(name=country, content_level=0)

admin_gdf = reproject_gdf(admin_gdf, crs)
admin_gdf["is_within_raster"] = admin_gdf["geometry_proj"].apply(
    lambda geom: geom.within(polygon)
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Following regions are available:

# %%
regions_within = admin_gdf[admin_gdf.is_within_raster].NAME_2.tolist()
print(", ".join(regions_within))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Al Buraiqeh, Al Mansura, Al Mualla, Ash Shaikh Outhman, Attawahi, Craiter, Dar Sad, Khur Maksar, Al Wade'a, Jayshan, Khanfir, Lawdar, Mudiyah, Rasad, Sarar, Sibah, Zingibar, Al A'rsh, Al Bayda, Al Bayda City, Al Malagim, Al Quraishyah, Ar Ryashyyah, As Sawadiyah, As Sawma'ah, Ash Sharyah, At Taffah, Az Zahir, Dhi Na'im, Maswarah, Mukayras, Na'man, Nati', Radman Al Awad, Sabah, Wald Rabi', Ad Dhale'e, Al Azariq, Al Husha, Al Hussein, Ash Shu'ayb, Damt, Jahaf, Juban, Qa'atabah, Al Garrahi, Al Hajjaylah, Al Mansuriyah, Al Mighlaf, As Sukhnah, Bura, Hays, Jabal Ra's, Zabid, Al Mahwait City, Bani Sa'd, Hufash, Milhan, Al Wahdah, As Sabain, Assafi'yah, At Tahrir, Ath'thaorah, Az'zal, Ma'ain, Old City, Shu'aub, Al Hada, Al Manar, Anss, Dawran Aness, Dhamar City, Jabal Ash sharq, Jahran, Maghirib Ans, Mayfa'at Anss, Utmah, Wusab Al Ali, Wusab As Safil, Al Dhihar, Al Makhadir, Al Mashannah, Al Qafr, Al Udayn, An Nadirah, Ar Radmah, As Sabrah, As Saddah, As Sayyani, Ash Sha'ir, Ba'dan, Dhi As Sufal, Far Al Udayn, Hazm Al Udayn, Hubaysh, Ibb, Jiblah, Mudhaykhirah, Yarim, Al Had, Al Hawtah, Al Madaribah Wa Al Arah, Al Maflahy, Al Maqatirah, Al Milah, Al Musaymir, Al Qabbaytah, Habil Jabr, Halimayn, Radfan, Tuban, Tur Al Bahah, Yafa'a, Yahr, Al Abdiyah, Al Jubah, Bidbadah, Harib, Harib Al Qaramish, Jabal Murad, Mahliyah, Marib City, Medghal, Rahabah, Sirwah, Al Jabin, Al Jafariyah, As Salafiyah, Bilad At Ta'am, Kusmah, Mazhar, Al Haymah Ad Dakhiliyah, Al Haymah Al Kharijiyah, Al Husn, Attyal, Bani Dhabyan, Bani Matar, Bilad Ar Rus, Jihanah, Khwlan, Manakhah, Sa'fan, Sanhan, Ain, Bayhan, Merkhah Al Ulya, Merkhah As Sufla, Usaylan, Al Ma'afer, Al Mawasit, Al Misrakh, Al Mudhaffar, Al Mukha, Al Qahirah, Al Wazi'iyah, As Silw, Ash Shamayatayn, At Ta'iziyah, Dhubab, Dimnat Khadir, Hayfan, Jabal Habashy, Maqbanah, Mashra'a Wa Hadnan, Mawiyah, Mawza, Sabir Al Mawadim, Salh, Sama, Shara'b Ar Rawnah, Shara'b As Salam

# %%
plot_admin_map_with_tiles(country_gdf, raster_gdf, admin_gdf, zoom_start=6)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_69a73b9e65d85d55b362060f5c0bef55 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_69a73b9e65d85d55b362060f5c0bef55&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_69a73b9e65d85d55b362060f5c0bef55 = L.map(
#                 &quot;map_69a73b9e65d85d55b362060f5c0bef55&quot;,
#                 {
#                     center: [15.904912553715363, 47.58411911117083],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b552c1b58d3e68e2b8f5ab205628e531 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b552c1b58d3e68e2b8f5ab205628e531.addTo(map_69a73b9e65d85d55b362060f5c0bef55);
#
#
#         function geo_json_0c005d131c4bf26181c3e4445647d719_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_0c005d131c4bf26181c3e4445647d719_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_0c005d131c4bf26181c3e4445647d719 = L.geoJson(null, {
#                 onEachFeature: geo_json_0c005d131c4bf26181c3e4445647d719_onEachFeature,
#
#                 style: geo_json_0c005d131c4bf26181c3e4445647d719_styler,
#             ...{
# }
#         });
#
#         function geo_json_0c005d131c4bf26181c3e4445647d719_add (data) {
#             geo_json_0c005d131c4bf26181c3e4445647d719
#                 .addData(data);
#         }
#             geo_json_0c005d131c4bf26181c3e4445647d719_add({&quot;bbox&quot;: [43.07830496757955, 12.262607837665367, 46.556820643582356, 15.813952251561744], &quot;features&quot;: [{&quot;bbox&quot;: [43.07830496757955, 12.262607837665367, 46.556820643582356, 15.813952251561744], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[45.13177767487347, 12.269125447196464], [43.1049207867242, 12.262607837665367], [43.07830496757955, 15.512951577362676], [44.512715339375035, 15.520774798660508], [44.51201983821477, 15.813952251561744], [46.556820643582356, 15.808920218418509], [46.534510597733835, 12.512110045753023], [45.131901928366254, 12.516452972667707], [45.13177767487347, 12.269125447196464]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_0c005d131c4bf26181c3e4445647d719.addTo(map_69a73b9e65d85d55b362060f5c0bef55);
#
#
#         function geo_json_b7009147be89f06f7c3c2f89a149f2ed_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#07407B&quot;, &quot;fillColor&quot;: &quot;#07407B&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_b7009147be89f06f7c3c2f89a149f2ed_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_b7009147be89f06f7c3c2f89a149f2ed = L.geoJson(null, {
#                 onEachFeature: geo_json_b7009147be89f06f7c3c2f89a149f2ed_onEachFeature,
#
#                 style: geo_json_b7009147be89f06f7c3c2f89a149f2ed_styler,
#             ...{
# }
#         });
#
#         function geo_json_b7009147be89f06f7c3c2f89a149f2ed_add (data) {
#             geo_json_b7009147be89f06f7c3c2f89a149f2ed
#                 .addData(data);
#         }
#             geo_json_b7009147be89f06f7c3c2f89a149f2ed_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[44.8857, 12.733], [44.8876, 12.7285], [44.8843, 12.7274], [44.8829, 12.7321], [44.8857, 12.733]]], [[[44.9193, 12.7563], [44.9193, 12.7538], [44.9162, 12.7549], [44.9168, 12.7563], [44.9193, 12.7563]]], [[[44.7159, 12.7418], [44.7196, 12.7334], [44.714, 12.7307], [44.7102, 12.7324], [44.7074, 12.7313], [44.7051, 12.7374], [44.7076, 12.7379], [44.7093, 12.7349], [44.7132, 12.7354], [44.7159, 12.7418]]], [[[44.7446, 12.7543], [44.7454, 12.7524], [44.7432, 12.7507], [44.7429, 12.7541], [44.7446, 12.7543]]], [[[44.9607, 12.8301], [44.9576, 12.8296], [44.9565, 12.8324], [44.9401, 12.8315], [44.9365, 12.8276], [44.9321, 12.8274], [44.9301, 12.8238], [44.9218, 12.8218], [44.9171, 12.8182], [44.9143, 12.8185], [44.9124, 12.816], [44.9074, 12.8143], [44.8957, 12.7951], [44.8946, 12.7826], [44.891, 12.7732], [44.8887, 12.

# %% [markdown]
# ## Ethiopia

# %%
country = "Ethiopia"

tiles_paths = get_tiles_paths(country)
polygon, crs = get_raster_polygon(*tiles_paths)

raster_gdf = get_raster_gdf(*tiles_paths, crs="EPSG:4326")
admin_gdf = pygadm.Items(name=country, content_level=2)
country_gdf = pygadm.Items(name=country, content_level=0)

admin_gdf = reproject_gdf(admin_gdf, crs)
admin_gdf["is_within_raster"] = admin_gdf["geometry_proj"].apply(
    lambda geom: geom.within(polygon)
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Following regions are available:

# %%
regions_within = admin_gdf[admin_gdf.is_within_raster].NAME_2.tolist()
print(", ".join(regions_within))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Bahir Dar Special Zone, Wag Himra, Debubawi, Mehakelegnaw, Misraqawi

# %%
plot_admin_map_with_tiles(country_gdf, raster_gdf, admin_gdf, zoom_start=6)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7f2e9791989168c50fc406e04d3687fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7f2e9791989168c50fc406e04d3687fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7f2e9791989168c50fc406e04d3687fb = L.map(
#                 &quot;map_7f2e9791989168c50fc406e04d3687fb&quot;,
#                 {
#                     center: [8.628690783192798, 39.625021347471694],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_40c32cef98eba05293cb5efff368d7ef = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_40c32cef98eba05293cb5efff368d7ef.addTo(map_7f2e9791989168c50fc406e04d3687fb);
#
#
#         function geo_json_d62aee9af8bda4aa5338e9782013fbc6_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_d62aee9af8bda4aa5338e9782013fbc6_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_d62aee9af8bda4aa5338e9782013fbc6 = L.geoJson(null, {
#                 onEachFeature: geo_json_d62aee9af8bda4aa5338e9782013fbc6_onEachFeature,
#
#                 style: geo_json_d62aee9af8bda4aa5338e9782013fbc6_styler,
#             ...{
# }
#         });
#
#         function geo_json_d62aee9af8bda4aa5338e9782013fbc6_add (data) {
#             geo_json_d62aee9af8bda4aa5338e9782013fbc6
#                 .addData(data);
#         }
#             geo_json_d62aee9af8bda4aa5338e9782013fbc6_add({&quot;bbox&quot;: [36.79626035110667, 11.401294358817516, 40.26901822181436, 14.9703305382659], &quot;features&quot;: [{&quot;bbox&quot;: [36.79626035110667, 11.401294358817516, 40.26901822181436, 14.9703305382659], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[38.85148817122451, 11.40931293848925], [36.8249986390025, 11.401294358817516], [36.79626035110667, 14.668181862279566], [38.22874279421767, 14.67735481112762], [38.22770482589077, 14.9703305382659], [40.26901822181436, 14.968108381117833], [40.251870386228966, 11.65394329464108], [38.851358148006184, 11.656628554825824], [38.85148817122451, 11.40931293848925]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_d62aee9af8bda4aa5338e9782013fbc6.addTo(map_7f2e9791989168c50fc406e04d3687fb);
#
#
#         function geo_json_4266a9267f85948917b17edb92ba7393_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#F7931F&quot;, &quot;fillColor&quot;: &quot;#F7931F&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_4266a9267f85948917b17edb92ba7393_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_4266a9267f85948917b17edb92ba7393 = L.geoJson(null, {
#                 onEachFeature: geo_json_4266a9267f85948917b17edb92ba7393_onEachFeature,
#
#                 style: geo_json_4266a9267f85948917b17edb92ba7393_styler,
#             ...{
# }
#         });
#
#         function geo_json_4266a9267f85948917b17edb92ba7393_add (data) {
#             geo_json_4266a9267f85948917b17edb92ba7393
#                 .addData(data);
#         }
#             geo_json_4266a9267f85948917b17edb92ba7393_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[38.8794, 8.9183], [38.8733, 8.9051], [38.8775, 8.8958], [38.8698, 8.8808], [38.8687, 8.873], [38.8638, 8.8829], [38.8584, 8.8836], [38.8471, 8.88], [38.8407, 8.8799], [38.833, 8.8829], [38.826, 8.8802], [38.8294, 8.8688], [38.8239, 8.8528], [38.8244, 8.8413], [38.8175, 8.8393], [38.8125, 8.84], [38.7976, 8.8335], [38.792, 8.8358], [38.7806, 8.8359], [38.7784, 8.8418], [38.7775, 8.8524], [38.773, 8.8575], [38.7565, 8.8532], [38.7541, 8.8586], [38.7455, 8.8634], [38.7452, 8.8695], [38.7473, 8.8772], [38.7432, 8.8804], [38.7445, 8.8921], [38.7436, 8.9026], [38.7365, 8.9013], [38.7311, 8.9051], [38.7191, 8.9197], [38.7084, 8.9209], [38.702, 8.9256], [38.6968, 8.9327], [38.6938, 8.9419], [38.6879, 8.9397], [38.6806, 8.9411], [38.681, 8.9497], [38.6762, 8.9576], [38.6428, 8.9659], [38.6394, 8.974], [38.6546, 8.9769], [38.6594, 8.98

# %% [markdown]
# ## Myanmar

# %%
country = "Myanmar"

tiles_paths = get_tiles_paths(country)
polygon, crs = get_raster_polygon(*tiles_paths)

raster_gdf = get_raster_gdf(*tiles_paths, crs="EPSG:4326")
admin_gdf = pygadm.Items(name=country, content_level=2)
country_gdf = pygadm.Items(name=country, content_level=0)

admin_gdf = reproject_gdf(admin_gdf, crs)
admin_gdf["is_within_raster"] = admin_gdf["geometry_proj"].apply(
    lambda geom: geom.within(polygon)
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Following regions are available:

# %%
regions_within = admin_gdf[admin_gdf.is_within_raster].NAME_2.tolist()
print(", ".join(regions_within))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Minbu, Buthidaung, Maungtaw, Sittwe

# %%
plot_admin_map_with_tiles(country_gdf, raster_gdf, admin_gdf, zoom_start=6)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80f8008c1333fb073a73b3945571c340 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80f8008c1333fb073a73b3945571c340&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_80f8008c1333fb073a73b3945571c340 = L.map(
#                 &quot;map_80f8008c1333fb073a73b3945571c340&quot;,
#                 {
#                     center: [21.117397797719313, 96.5101812898422],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c60cff93257e0b4778f9230be2d3d8cc = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c60cff93257e0b4778f9230be2d3d8cc.addTo(map_80f8008c1333fb073a73b3945571c340);
#
#
#         function geo_json_c71fcbe6dbab3485e8d9a425614459c9_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_c71fcbe6dbab3485e8d9a425614459c9_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_c71fcbe6dbab3485e8d9a425614459c9 = L.geoJson(null, {
#                 onEachFeature: geo_json_c71fcbe6dbab3485e8d9a425614459c9_onEachFeature,
#
#                 style: geo_json_c71fcbe6dbab3485e8d9a425614459c9_styler,
#             ...{
# }
#         });
#
#         function geo_json_c71fcbe6dbab3485e8d9a425614459c9_add (data) {
#             geo_json_c71fcbe6dbab3485e8d9a425614459c9
#                 .addData(data);
#         }
#             geo_json_c71fcbe6dbab3485e8d9a425614459c9_add({&quot;bbox&quot;: [91.64287670967059, 18.334411921788394, 95.30953459399488, 21.948929983463557], &quot;features&quot;: [{&quot;bbox&quot;: [91.64287670967059, 18.334411921788394, 95.30953459399488, 21.948929983463557], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[93.80156615942818, 18.337359118653083], [91.67089892595205, 18.334411921788394], [91.64287670967059, 21.639118023860664], [93.14410299246046, 21.644597926747647], [93.14440764209743, 21.948929983463557], [95.30953459399488, 21.932762713576086], [95.26061663985621, 18.593410375564243], [93.80281164677596, 18.605266126237748], [93.80156615942818, 18.337359118653083]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_c71fcbe6dbab3485e8d9a425614459c9.addTo(map_80f8008c1333fb073a73b3945571c340);
#
#
#         function geo_json_a93b087ce6318d4eba7d5ce77e3fe7f6_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#F7931F&quot;, &quot;fillColor&quot;: &quot;#F7931F&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_a93b087ce6318d4eba7d5ce77e3fe7f6_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_a93b087ce6318d4eba7d5ce77e3fe7f6 = L.geoJson(null, {
#                 onEachFeature: geo_json_a93b087ce6318d4eba7d5ce77e3fe7f6_onEachFeature,
#
#                 style: geo_json_a93b087ce6318d4eba7d5ce77e3fe7f6_styler,
#             ...{
# }
#         });
#
#         function geo_json_a93b087ce6318d4eba7d5ce77e3fe7f6_add (data) {
#             geo_json_a93b087ce6318d4eba7d5ce77e3fe7f6
#                 .addData(data);
#         }
#             geo_json_a93b087ce6318d4eba7d5ce77e3fe7f6_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[94.2786, 15.8681], [94.2803, 15.8658], [94.2797, 15.8633], [94.2744, 15.8589], [94.2719, 15.8614], [94.2725, 15.8642], [94.2753, 15.8664], [94.2761, 15.8697], [94.2786, 15.8681]]], [[[94.2154, 16.3798], [94.2148, 16.3773], [94.2121, 16.3776], [94.2136, 16.3818], [94.2152, 16.3819], [94.2154, 16.3798]]], [[[94.2235, 16.3831], [94.2233, 16.3915], [94.2264, 16.3941], [94.2289, 16.3914], [94.2281, 16.3854], [94.2256, 16.3804], [94.2235, 16.3811], [94.2235, 16.3831]]], [[[94.2283, 16.4217], [94.2299, 16.4223], [94.2305, 16.421], [94.2288, 16.4198], [94.2283, 16.4217]]], [[[94.3448, 16.0188], [94.3487, 16.0151], [94.34, 16.0045], [94.3353, 15.9933], [94.3289, 15.9881], [94.3255, 15.9786], [94.2981, 15.9858], [94.2889, 15.985], [94.28, 15.9867], [94.2758, 15.9903], [94.2792, 15.9939], [94.2931, 15.9983], [94.3025, 16.0072],

# %% [markdown]
# ## Nigeria

# %%
country = "Nigeria"

tiles_paths = get_tiles_paths(country)
polygon, crs = get_raster_polygon(*tiles_paths)

raster_gdf = get_raster_gdf(*tiles_paths, crs="EPSG:4326")
admin_gdf = pygadm.Items(name=country, content_level=2)
country_gdf = pygadm.Items(name=country, content_level=0)

admin_gdf = reproject_gdf(admin_gdf, crs)
admin_gdf["is_within_raster"] = admin_gdf["geometry_proj"].apply(
    lambda geom: geom.within(polygon)
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Following regions are available:

# %%
regions_within = admin_gdf[admin_gdf.is_within_raster].NAME_2.tolist()
print(", ".join(regions_within))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Hong, Madagali, Michika, Mubi North, Mubi South, Askira/Uba, Bama, Chibok, Dikwa, Gubio, Guzamala, Gwoza, Jere, Kala/Balge, Konduga, Mafa, Maiduguri, Marte, Monguno, Ngala, Nganzai

# %%
plot_admin_map_with_tiles(country_gdf, raster_gdf, admin_gdf, zoom_start=6)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d4655d10d51c05bc7efa9d2475502b0d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d4655d10d51c05bc7efa9d2475502b0d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d4655d10d51c05bc7efa9d2475502b0d = L.map(
#                 &quot;map_d4655d10d51c05bc7efa9d2475502b0d&quot;,
#                 {
#                     center: [9.592277139323686, 8.0975890706822],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82d4602e947660ae4e76b9d5a297121b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_82d4602e947660ae4e76b9d5a297121b.addTo(map_d4655d10d51c05bc7efa9d2475502b0d);
#
#
#         function geo_json_35e7a81062fbc550f147b3d73a5c946f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_35e7a81062fbc550f147b3d73a5c946f_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_35e7a81062fbc550f147b3d73a5c946f = L.geoJson(null, {
#                 onEachFeature: geo_json_35e7a81062fbc550f147b3d73a5c946f_onEachFeature,
#
#                 style: geo_json_35e7a81062fbc550f147b3d73a5c946f_styler,
#             ...{
# }
#         });
#
#         function geo_json_35e7a81062fbc550f147b3d73a5c946f_add (data) {
#             geo_json_35e7a81062fbc550f147b3d73a5c946f
#                 .addData(data);
#         }
#             geo_json_35e7a81062fbc550f147b3d73a5c946f_add({&quot;bbox&quot;: [12.34910356776622, 9.939646109431118, 15.823562330448867, 13.53370072279028], &quot;features&quot;: [{&quot;bbox&quot;: [12.34910356776622, 9.939646109431118, 15.823562330448867, 13.53370072279028], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[14.406529819490231, 9.94938000300125], [12.379954927384587, 9.939646109431118], [12.34910356776622, 13.229470497471706], [13.785032227472438, 13.240340275052445], [13.783568118306764, 13.53209922903942], [15.823562330448867, 13.53370072279028], [15.813606040119518, 10.196558093191976], [14.406076897703432, 10.197031333534378], [14.406529819490231, 9.94938000300125]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_35e7a81062fbc550f147b3d73a5c946f.addTo(map_d4655d10d51c05bc7efa9d2475502b0d);
#
#
#         function geo_json_fe15838643e4bf8a8691c9077c309697_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#F7931F&quot;, &quot;fillColor&quot;: &quot;#F7931F&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_fe15838643e4bf8a8691c9077c309697_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_fe15838643e4bf8a8691c9077c309697 = L.geoJson(null, {
#                 onEachFeature: geo_json_fe15838643e4bf8a8691c9077c309697_onEachFeature,
#
#                 style: geo_json_fe15838643e4bf8a8691c9077c309697_styler,
#             ...{
# }
#         });
#
#         function geo_json_fe15838643e4bf8a8691c9077c309697_add (data) {
#             geo_json_fe15838643e4bf8a8691c9077c309697
#                 .addData(data);
#         }
#             geo_json_fe15838643e4bf8a8691c9077c309697_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[7.3781, 5.057], [7.369, 5.057], [7.3777, 5.0815], [7.3777, 5.0937], [7.376, 5.1025], [7.3668, 5.1076], [7.3655, 5.113], [7.3585, 5.113], [7.3428, 5.1095], [7.3333, 5.0891], [7.3223, 5.0874], [7.3148, 5.088], [7.3213, 5.0987], [7.3499, 5.1282], [7.3654, 5.1258], [7.372, 5.1232], [7.3777, 5.1201], [7.3836, 5.1121], [7.3856, 5.107], [7.3849, 5.0921], [7.3867, 5.0773], [7.3835, 5.0647], [7.3781, 5.057]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_fe15838643e4bf8a8691c9077c309697.addTo(map_d4655d10d51c05bc7efa9d2475502b0d);
#
#
#         function geo_json_f0fa692a411a433caa97b17c657586e0_styler(feature) {
#             switch(feature.id) {
#                 defa

# %% [markdown]
# ## South Sudan

# %%
country = "South Sudan"

tiles_paths = get_tiles_paths(country)
polygon, crs = get_raster_polygon(*tiles_paths)

raster_gdf = get_raster_gdf(*tiles_paths, crs="EPSG:4326")
admin_gdf = pygadm.Items(name=country, content_level=2)
country_gdf = pygadm.Items(name=country, content_level=0)

admin_gdf = reproject_gdf(admin_gdf, crs)
admin_gdf["is_within_raster"] = admin_gdf["geometry_proj"].apply(
    lambda geom: geom.within(polygon)
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# Following regions are available:

# %%
regions_within = admin_gdf[admin_gdf.is_within_raster].NAME_2.tolist()
print(", ".join(regions_within))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Akobo, Ayod, Wat, Yerol, Al Leiri

# %%
plot_admin_map_with_tiles(country_gdf, raster_gdf, admin_gdf, zoom_start=6)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b26e25b7962625ae2308dd1ac6862e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b26e25b7962625ae2308dd1ac6862e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7b26e25b7962625ae2308dd1ac6862e6 = L.map(
#                 &quot;map_7b26e25b7962625ae2308dd1ac6862e6&quot;,
#                 {
#                     center: [7.287271344932998, 30.32141752025594],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b7f1bd67863ca5170fec9b336037c42c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b7f1bd67863ca5170fec9b336037c42c.addTo(map_7b26e25b7962625ae2308dd1ac6862e6);
#
#
#         function geo_json_e674a6d4182f98988b4640105b6a4685_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;black&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_e674a6d4182f98988b4640105b6a4685_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_e674a6d4182f98988b4640105b6a4685 = L.geoJson(null, {
#                 onEachFeature: geo_json_e674a6d4182f98988b4640105b6a4685_onEachFeature,
#
#                 style: geo_json_e674a6d4182f98988b4640105b6a4685_styler,
#             ...{
# }
#         });
#
#         function geo_json_e674a6d4182f98988b4640105b6a4685_add (data) {
#             geo_json_e674a6d4182f98988b4640105b6a4685
#                 .addData(data);
#         }
#             geo_json_e674a6d4182f98988b4640105b6a4685_add({&quot;bbox&quot;: [29.482170462388606, 5.874748217477375, 32.86254338737594, 9.42496939084992], &quot;features&quot;: [{&quot;bbox&quot;: [29.482170462388606, 5.874748217477375, 32.86254338737594, 9.42496939084992], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[31.485547956325895, 5.883615586921149], [29.50820777434524, 5.874748217477375], [29.482170462388606, 9.124456535018684], [30.8820240401753, 9.135322675896324], [30.880323131200505, 9.418621613149261], [32.86146552103141, 9.42496939084992], [32.86254338737594, 6.12694359776595], [31.484881514590104, 6.124821240204356], [31.485547956325895, 5.883615586921149]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_e674a6d4182f98988b4640105b6a4685.addTo(map_7b26e25b7962625ae2308dd1ac6862e6);
#
#
#         function geo_json_4c160036772b0f915f29f69aa9789df8_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#F7931F&quot;, &quot;fillColor&quot;: &quot;#F7931F&quot;, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_4c160036772b0f915f29f69aa9789df8_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_4c160036772b0f915f29f69aa9789df8 = L.geoJson(null, {
#                 onEachFeature: geo_json_4c160036772b0f915f29f69aa9789df8_onEachFeature,
#
#                 style: geo_json_4c160036772b0f915f29f69aa9789df8_styler,
#             ...{
# }
#         });
#
#         function geo_json_4c160036772b0f915f29f69aa9789df8_add (data) {
#             geo_json_4c160036772b0f915f29f69aa9789df8
#                 .addData(data);
#         }
#             geo_json_4c160036772b0f915f29f69aa9789df8_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[32.2158, 4.5975], [32.1777, 4.5558], [32.1037, 4.5301], [32.0676, 4.4959], [32.07, 4.2686], [32.0001, 4.1668], [32.0031, 4.1164], [31.9925, 4.1086], [31.9855, 4.078], [31.9578, 4.0896], [31.9062, 4.0693], [31.8573, 4.042], [31.7643, 4.037], [31.7212, 3.9928], [31.759, 3.9136], [31.7768, 3.8845], [31.8011, 3.835], [31.8025, 3.8249], [31.796, 3.8226], [31.7713, 3.8314], [31.7565, 3.8406], [31.7307, 3.8647], [31.7124, 3.8934], [31.6922, 3.9124], [31.6554, 3.9161], [31.6103, 3.9495], [31.5772, 3.9814], [31.5904, 3.994], [31.3712, 4.3192], [31.3229, 4.3323], [31.2358, 4.3933], [31.1599, 4.4345], [31.1285, 4.4447], [31.0289, 4.4027], [31.013, 4.4014], [30.9454, 4.4636], [30.8783, 4.5304], [30.7813, 4.6171], [30.6916, 4.6451], [30.6598, 4.6641], [30.5682, 4.8162], [30.6859, 4.8523], [30.7504, 4.8977], [30.7976, 4.9355], [30.8445, 4.941
